# %% [markdown]
# ## 1. Get Tweets

# %%
import pandas as pd

pd.options.display.max_columns = 999
pd.options.display.max_colwidth = 999
pd.options.display.max_rows = 999

# %%
# Solve compatibility issues with notebooks and RunTime errors.
import nest_asyncio
nest_asyncio.apply()

# %%
import twint
# [https://github.com/twintproject/twint]

# %%
# Set up TWINT config
c = twint.Config()

# %%
c.Search = "Künast"

# %%
# Custom output format
c.Format = "Datum: {date} | Username: {username} |  Tweet: {tweet} | "
c.Pandas = True
c.Since = '2018-12-31'
c.Until = '2019-06-30'
c.Show_hashtags = True
twint.run.Search(c)
# Out:
# Datum: 2019-06-29 | Username: wolfgs2 |  Tweet: Pädophile bei den Grünen: Renate Künast gerät in Erklärungsnot - WELT  https://www.welt.de/politik/deutschland/article141406874/Gruenen-Politikerin-Kuenast-geraet-in-Erklaerungsnot.html … |
# Datum: 2019-06-29 | Username: weigl_ |  Tweet: ISRC’s Portier mit lukrativem Vertrag mit den US tort lawyers. Stinkt zum Himmel. Das BfR wurde 2003 von der grünen Ministerin Künast auf wissenschaftliche Unabhängigkeit hin eingerichtet. Gut, dass sich mit CRISPR die Anti GMO Hysterie sowieso gegessen hat. |
# Datum: 2019-06-29 | Username: LunaLara404 |  Tweet: Das manche ältere Herren immer wieder großen Mist von sich geben, quasi ohne Konsequenzen, Seehofer, Gabriel, habe ich kein Verständnis für. Aber auch in den älteren Generationen gibt es Positivbeispiele, Polenz, Künast… |
# ...

# %%
Künast_df = twint.storage.panda.Tweets_df

# %%
Künast_df.to_pickle('01_Künast.pkl')

# %%
Künast_df.shape
# Out:
# (2992, 30)

# %%
c.Search = "#Kuenast"

# %%
# Custom output format
c.Format = "Datum: {date} | Username: {username} |  Tweet: {tweet} | "
c.Pandas = True
c.Since = '2018-12-31'
c.Until = '2019-06-30'
c.Show_hashtags = True
twint.run.Search(c)
# Out:
# Datum: 2019-06-29 | Username: exveganer |  Tweet: Die (((#Grünen))) eben. Informiere Dich. Es geht nicht primär um Öko. Es geht um die Farbe und was damit verbunden ist. Wie bei Leuten mit Namen wie #Greenspan, #Greenhill, #Roth, #Künast/#Kynast/#Kienast etc. |
# Datum: 2019-06-28 | Username: NorEmpok |  Tweet: Peinliche Frage 🙄 #künast #antisemit |
# Datum: 2019-06-25 | Username: Konverter53 |  Tweet: Diese Ausweisung möchte ich erleben!!!!! Gerade in Hamburg und Berlin 🤣 Geht ja nicht …. das waren doch die deutschen Rechten!!!! Übrigens wird bestimmt der Ehemann der Frau #Künast  die Verteidigung übernehmen. Ist ja die Familiengrundlage der #Grünen!!!! |
# Datum: 2019-06-24 | Username: ARichartz |  Tweet: Die "problematischen Wahrnehmung" liegt ganz alleine bei Ihnen Hr. Singelnstein! Schauen Sie die Peinlichkeiten zur #Polizei von z.B. Fr #kuenast aus den letzten Jahren an, dann sollten selbst Sie erkennen, dass Ihr Tweet an Lächerlichkeit nicht zu überbieten ist! |
# ...

# %%
Hash_Kuenast_df = twint.storage.panda.Tweets_df

# %%
Hash_Kuenast_df.to_pickle('02_Kuenast.pkl')

# %%
Hash_Kuenast_df.shape
# Out:
# (135, 30)

# %%
Künast_df.sample()
# Out:
#                       id      conversation_id     created_at  \
# 747  1130410129176895488  1130410129176895488  1558345751000
#
#                     date timezone place  \
# 747  2019-05-20 11:49:11     CEST
#
#                                                                                           tweet  \
# 747  Renate Künast: „Wir werden uns anders ernähren müssen“  https://buff.ly/2WQj7Pf  via @welt
#
#     hashtags cashtags             user_id         user_id_str      username  \
# 747       []       []  855083056604033027  855083056604033027  Friederike77
#
#                     name  day hour  \
# 747  Friederike Putensen    3   04
#
#                                                             link  retweet  \
# 747  https://twitter.com/Friederike77/status/1130410129176895488    False
#
#      nlikes  nreplies  nretweets quote_url  search near geo source user_rt_id  \
# 747       2         0          0            Künast
#
#     user_rt retweet_id  \
# 747
#
# ...

# %%
Hash_Kuenast_df.sample()
# Out:
#                      id      conversation_id     created_at  \
# 39  1132018203146821633  1131828745822720001  1558729146000
#
#                    date timezone place  \
# 39  2019-05-24 22:19:06     CEST
#
#                                              tweet   hashtags cashtags  \
# 39  😜… und ich kenne nur #Künast !!!! Passt doch 😜  [#künast]       []
#
#                 user_id          user_id_str     username       name  day  \
# 39  1081223310543908864  1081223310543908864  Konverter53  Konverter    2
#
#    hour                                                        link  retweet  \
# 39   15  https://twitter.com/Konverter53/status/1132018203146821633    False
#
#     nlikes  nreplies  nretweets quote_url    search near geo source  \
# 39       0         0          0            #Kuenast
#
#    user_rt_id user_rt retweet_id  \
# 39
#
# ...
